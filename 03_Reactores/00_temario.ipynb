# %% [markdown]
# # Cinética de Procesos (Sesión 03)

# %% [markdown]
# <img src="figures/LogoCinvestav.png" style="height:100px" title="Cinvestav">

# %% [markdown]
# **CINVESTAV Unidad Saltillo**
#
# **Programa de Maestría en Ciencias en Ingeniería Metalúrgica**
#
# Dr. Edgar Ivan Castro Cedeño
#
#
# 2025
#
# Contacto:
# [edgar.castro@cinvestav.mx](mailto:edgar.castro@cinvestav.mx)

# %% [markdown]
# # Contenido de la sesión

# %% [markdown]
# **1. Reactores ideales. Características fluidinámicas y comportamiento químico**
#
#
# - **1.1** Reactores discontinuos (BR).
#
# - **1.2** Reactor Agitado de Flujo Continuo (CSTR).
#
# - **1.3** Reactor de Flujo Pistón (PFR).
#
# - **1.4** Reactor de Lecho Empacado (PBR).

# %% [markdown]
# **2. Dimensionamiento de un Reactor Ideal**
#
# - **2.1** Ecuaciones para dimensionamiento de reactores ideales.
#
# - **2.2** Gráfica de Levenspiel.
#
# - **2.3** Comparación de rendimiento CSTR vs PFR.

# %% [markdown]
# **3. Dimensionamiento de Reactores en Serie y en Paralelo**
#
# - **3.1** Reactores CSTR.
#
# - **3.2** Reactores PFR.
#
# - **3.3** Arreglos diversos.
#
# - **3.4** Reactores con recirculación

# %% [markdown]
# **4. Reacciones autocatalíticas**
#
# - **4.1** Definiciones.
#
# - **4.2** Reactores CSTR / PFR.
#
# - **4.3** Arreglos de reactores.

# %% [markdown]
# **5. Reactores Semi-batch**
#
# - **5.1** Definiciones
#
# - **5.2** Aplicaciones numéricas de la ecuacion de diseño
